# %%
#Setting up dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import json

#Reading CSV files 
budget_df = pd.read_csv("Agency_Spending_by_Budget_Function.csv")
budget_df.head()

#Setting up API - note that this file only has 2015 and 2016 data
url = "https://data.ny.gov/resource/k397-673e.json"
payroll_df = requests.get(url).json()
payroll_df
#^the data imports but needs to be cleaned into a dataframe
# Out:
# [{'fiscal_year': '2019', 'payroll_number': '67', 'agency_name': "ADMIN FOR CHILDREN'S SVCS", 'last_name': 'ROGERS', 'first_name': 'CAROL', 'mid_init': 'N', 'agency_start_date': '1996-06-23T00:00:00.000', 'work_location_borough': 'QUEENS', 'title_description': 'CHILD PROTECTIVE SPECIALIST SUPERVISOR', 'leave_status_as_of_july_31': 'ACTIVE', 'base_salary': '83879.00', 'pay_basis': 'per Annum', 'regular_hours': '1825.00', 'regular_gross_paid': '84375.24', 'ot_hours': '419.75', 'total_ot_paid': '27522.09', 'total_other_pay': '5118.11'}, {'fiscal_year': '2019', 'payroll_number': '67', 'agency_name': "ADMIN FOR CHILDREN'S SVCS", 'last_name': 'HUGGINS', 'first_name': 'DONETT', 'agency_start_date': '1997-09-15T00:00:00.000', 'work_location_borough': 'RICHMOND', 'title_description': 'DIRECTOR OF FIELD OPERATIONS', 'leave_status_as_of_july_31': 'ACTIVE', 'base_salary': '110000.00', 'pay_basis': 'per Annum', 'regular_hours': '1825.00', 'regular_gross_paid': '103029.44', 'ot_hours': '0.00', 'tot
# ...
